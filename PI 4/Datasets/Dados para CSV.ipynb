# %%
import pandas as pd

file_names = ['GLOBAL_DATAFLOW_2000-2005.xlsx','GLOBAL_DATAFLOW_2006-2010.xlsx', 'GLOBAL_DATAFLOW_2011-2015.xlsx','GLOBAL_DATAFLOW_2016-2023.xlsx']
df_list = []
for file_name in file_names:
    df = pd.read_excel(file_name)
    df_list.append(df)
df_concat = pd.concat(df_list)

df_concat.to_csv('dados.csv', index=False)

# %%
df = pd.read_csv('dados.csv')

# %%
df
# Out:
#                       PAIS           INDICADOR GENERO   ANO   VALOR  \
# 0              Afghanistan  Deaths 1-59 months  Total  2000   62123
# 1              Afghanistan  Deaths 1-59 months  Total  2001   62126
# 2              Afghanistan  Deaths 1-59 months  Total  2002   58917
# 3              Afghanistan  Deaths 1-59 months  Total  2003   55943
# 4              Afghanistan  Deaths 1-59 months  Total  2004   56301
# ...                    ...                 ...    ...   ...     ...
# 147835  sub-Saharan Africa  Deaths aged 5 to 9  Total  2017  316124
# 147836  sub-Saharan Africa  Deaths aged 5 to 9  Total  2018  314751
# 147837  sub-Saharan Africa  Deaths aged 5 to 9  Total  2019  313483
# 147838  sub-Saharan Africa  Deaths aged 5 to 9  Total  2020  310761
# 147839  sub-Saharan Africa  Deaths aged 5 to 9  Total  2021  307843
#
#                  UNIDADE
# 0       Number of deaths
# 1       Number of deaths
# 2       Number of deaths
# 3       Number of deaths
# ...
